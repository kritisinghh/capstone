# %% [markdown]
# <a href="https://colab.research.google.com/github/kritisinghh/capstone/blob/main/lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gymnasium stable-baselines3 sb3-contrib numpy pandas scikit-learn
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.5.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.5.1+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (3.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 2.5 MB/s eta 0:00:00
# Downloading sb3_contrib-2.5.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 3.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 16.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 9.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 38.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3, sb3-contrib
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 sb3-contrib-2.5.0 stable-baselines3-2.5.0

# %%
import gymnasium as gym
from sb3_contrib import RecurrentPPO
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

def preprocess_data(df):
    categorical_cols = ["eclass", "route", "type"]
    encoder = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
    encoded_data = encoder.fit_transform(df[categorical_cols])

    encoded_df = pd.DataFrame(
        encoded_data,
        columns=encoder.get_feature_names_out(categorical_cols)
    )

    df = df.drop(columns=categorical_cols)
    df = pd.concat([df, encoded_df], axis=1)

    return df

class TrafficSignalEnv(gym.Env):
    def __init__(self, df, sequence_length=5):
        super().__init__()
        self.df = df
        self.current_step = 0
        self.max_steps = len(df) - 1
        self.sequence_length = sequence_length

        self.action_space = gym.spaces.Discrete(3)
        self.observation_space = gym.spaces.Box(
            low=-np.inf, high=np.inf, shape=(len(df.columns) - 1,), dtype=np.float32
        )

    def reset(self, **kwargs):
        self.current_step = np.random.randint(0, self.max_steps)
        obs = np.array(self.df.iloc[self.current_step, 1:].values, dtype=np.float32).flatten()
        return obs, {}

    def step(self, action):
        co2 = self.df.at[self.current_step, "CO2"]
        fuel = self.df.at[self.current_step, "fuel"]

        if self.current_step > 0:
            prev_co2 = self.df.at[self.current_step - 1, "CO2"]
            prev_fuel = self.df.at[self.current_step - 1, "fuel"]
            co2_reduction = prev_co2 - co2
            fuel_reduction = prev_fuel - fuel
        else:
            co2_reduction = 0
            fuel_reduction = 0

        reward = co2_reduction + fuel_reduction

        self.current_step += 1
        done = self.current_step >= self.max_steps
        truncated = False

        next_state = np.array(self.df.iloc[self.current_step, 1:].values, dtype=np.float32).flatten()
        return next_state, reward, done, truncated, {}

df = pd.read_csv("traffic_flow_dataset.csv")
df = preprocess_data(df)

env = DummyVecEnv([lambda: TrafficSignalEnv(df)])

model = RecurrentPPO("MlpLstmPolicy", env, verbose=1)

num_episodes = 500

for episode in range(num_episodes):
    obs = env.reset()
    done = False
    lstm_states = None
    initial_co2 = env.envs[0].df.at[env.envs[0].current_step, "CO2"]
    initial_fuel = env.envs[0].df.at[env.envs[0].current_step, "fuel"]

    final_co2 = initial_co2
    final_fuel = initial_fuel
    episode_starts = np.ones((1,), dtype=bool)

    while not done:
        action, lstm_states = model.predict(obs, state=lstm_states, episode_start=episode_starts, deterministic=False)
        obs, reward, done,  _ = env.step(action)
        episode_starts = np.array([done], dtype=bool)
        if env.envs[0].current_step > 0:
            final_co2 = env.envs[0].df.at[env.envs[0].current_step, "CO2"]
            final_fuel = env.envs[0].df.at[env.envs[0].current_step, "fuel"]

    co2_reduction = initial_co2 - final_co2
    fuel_reduction = initial_fuel - final_fuel

    print(f"Episode {episode + 1}: CO2 Reduction = {co2_reduction:.2f}, Fuel Reduction = {fuel_reduction:.2f}")

print("Training complete!")
# Out:
# Using cpu device
# Episode 1: CO2 Reduction = -21.73, Fuel Reduction = -0.06
# Episode 2: CO2 Reduction = 74.44, Fuel Reduction = -1.02
# Episode 3: CO2 Reduction = -12.03, Fuel Reduction = 3.42
# Episode 4: CO2 Reduction = -36.30, Fuel Reduction = -0.66
# Episode 5: CO2 Reduction = 23.27, Fuel Reduction = 0.41
# Episode 6: CO2 Reduction = -85.62, Fuel Reduction = 4.11
# Episode 7: CO2 Reduction = 90.31, Fuel Reduction = -7.06
# Episode 8: CO2 Reduction = -57.40, Fuel Reduction = 2.24
# Episode 9: CO2 Reduction = 69.06, Fuel Reduction = -1.15
# Episode 10: CO2 Reduction = 144.71, Fuel Reduction = 5.12
# Episode 11: CO2 Reduction = -76.68, Fuel Reduction = 0.36
# Episode 12: CO2 Reduction = 83.27, Fuel Reduction = 4.33
# Episode 13: CO2 Reduction = 46.13, Fuel Reduction = -5.44
# Episode 14: CO2 Reduction = 102.81, Fuel Reduction = -2.33
# Episode 15: CO2 Reduction = 50.04, Fuel Reduction = -5.22
# Episode 16: CO2 Reduction = -68.20, Fuel Reduction = -6.54
# Episode 17: CO2 Reduction = 20.24, Fuel Reduction = 5.03
# Episode 18: CO2 Reduction = 41.56, Fuel Reduction = -0.78
# Episode 19: CO2 Reduction = 80.69, Fuel Reduction = 2.51
# Episode 20: CO2 Reduction = 58.07, Fuel Reduction = 1.12
# Episode 21: CO2 Reduction = 106.67, Fuel Reduction = -4.53
# Episode 22: CO2 Reduction = -42.45, Fuel Reduction = -4.49
# Episode 23: CO2 Reduction = 3.41, Fuel Reduction = -2.65
# Episode 24: CO2 Reduction = 35.31, Fuel Reduction = 0.73
# Episode 25: CO2 Reduction = -33.64, Fuel Reduction = 7.49
# Episode 26: CO2 Reduction = 5.36, Fuel Reduction = -4.12
# Episode 27: CO2 Reduction = 54.58, Fuel Reduction = 3.43
# Episode 28: CO2 Reduction = 15.00, Fuel Reduction = 2.09
# Episode 29: CO2 Reduction = 19.93, Fuel Reduction = 2.86
# Episode 30: CO2 Reduction = -42.64, Fuel Reduction = 7.24
# Episode 31: CO2 Reduction = -43.70, Fuel Reduction = 3.30
# Episode 32: CO2 Reduction = -125.29, Fuel Reduction = -3.91
# Episode 33: CO2 Reduction = -43.27, Fuel Reduction = 1.97
# Episode 34: CO2 Reduction = -17.62, Fuel Reduction = -4.74
# Episode 35: CO2 Reduction = -7.04, Fuel Reduction = -2.95
# Episode 36: CO2 Reduction = -39.89, Fuel Reduction = 3.29
# Episode 37: CO2 Reduction = -114.25, Fuel Reduction = 0.05
# Episode 38: CO2 Reduction = 19.99, Fuel Reduction = -2.10
# Episode 39: CO2 Reduction = -47.06, Fuel Reduction = 3.50
# Episode 40: CO2 Reduction = 0.03, Fuel Reduction = -3.63
# Episode 41: CO2 Reduction = -28.96, Fuel Reduction = 2.24
# Episode 42: CO2 Reduction = 37.58, Fuel Reduction = 1.52
# Episode 43: CO2 Reduction = 15.72, Fuel Reduction = 6.70
# Episode 44: CO2 Reduction = 49.70, Fuel Reduction = -1.57
# Episode 45: CO2 Reduction = 6.20, Fuel Reduction = 3.70
# Episode 46: CO2 Reduction = 94.70, Fuel Reduction = -0.57
# Episode 47: CO2 Reduction = -43.52, Fuel Reduction = -1.52
# Episode 48: CO2 Reduction = 87.20, Fuel Reduction = 0.34
# Episode 49: CO2 Reduction = -57.10, Fuel Reduction = -0.64
# Episode 50: CO2 Reduction = -92.78, Fuel Reduction = 7.03
# Episode 51: CO2 Reduction = -2.11, Fuel Reduction = -1.50
# Episode 52: CO2 Reduction = -53.28, Fuel Reduction = -8.21
# Episode 53: CO2 Reduction = 97.22, Fuel Reduction = 5.26
# Episode 54: CO2 Reduction = 8.41, Fuel Reduction = -3.55
# Episode 55: CO2 Reduction = 70.90, Fuel Reduction = -1.46
# Episode 56: CO2 Reduction = -17.88, Fuel Reduction = -0.36
# Episode 57: CO2 Reduction = 65.71, Fuel Reduction = -5.06
# Episode 58: CO2 Reduction = -11.26, Fuel Reduction = 7.30
# Episode 59: CO2 Reduction = 36.80, Fuel Reduction = -0.58
# Episode 60: CO2 Reduction = 10.79, Fuel Reduction = -1.52
# Episode 61: CO2 Reduction = -71.04, Fuel Reduction = 0.66
# Episode 62: CO2 Reduction = -6.34, Fuel Reduction = -5.90
# Episode 63: CO2 Reduction = -125.08, Fuel Reduction = -6.80
# Episode 64: CO2 Reduction = 71.56, Fuel Reduction = 1.77
# Episode 65: CO2 Reduction = -90.59, Fuel Reduction = -1.05
# Episode 66: CO2 Reduction = 6.28, Fuel Reduction = -5.34
# Episode 67: CO2 Reduction = 59.47, Fuel Reduction = -0.43
# Episode 68: CO2 Reduction = 53.46, Fuel Reduction = 4.21
# Episode 69: CO2 Reduction = 33.35, Fuel Reduction = -4.63
# Episode 70: CO2 Reduction = -0.24, Fuel Reduction = 0.24
# Episode 71: CO2 Reduction = -89.88, Fuel Reduction = -2.15
# Episode 72: CO2 Reduction = -0.36, Fuel Reduction = -5.22
# Episode 73: CO2 Reduction = 116.75, Fuel Reduction = -0.57
# Episode 74: CO2 Reduction = 74.87, Fuel Reduction = 4.92
# Episode 75: CO2 Reduction = -45.51, Fuel Reduction = 4.14
# Episode 76: CO2 Reduction = -93.43, Fuel Reduction = -5.71
# Episode 77: CO2 Reduction = 109.89, Fuel Reduction = 5.77
# Episode 78: CO2 Reduction = 37.46, Fuel Reduction = 2.42
# Episode 79: CO2 Reduction = 30.56, Fuel Reduction = 1.05
# Episode 80: CO2 Reduction = 104.68, Fuel Reduction = -1.08
# Episode 81: CO2 Reduction = -4.74, Fuel Reduction = -1.44
# Episode 82: CO2 Reduction = 1.11, Fuel Reduction = 1.29
# Episode 83: CO2 Reduction = 32.30, Fuel Reduction = 3.23
# Episode 84: CO2 Reduction = -30.40, Fuel Reduction = 0.24
# Episode 85: CO2 Reduction = 55.61, Fuel Reduction = -0.46
# Episode 86: CO2 Reduction = -22.26, Fuel Reduction = 0.62
# Episode 87: CO2 Reduction = 1.68, Fuel Reduction = -7.64
# Episode 88: CO2 Reduction = 106.02, Fuel Reduction = 4.64
# Episode 89: CO2 Reduction = -20.25, Fuel Reduction = -5.36
# Episode 90: CO2 Reduction = -7.74, Fuel Reduction = -0.47
# Episode 91: CO2 Reduction = 58.10, Fuel Reduction = -3.52
# Episode 92: CO2 Reduction = 136.10, Fuel Reduction = 0.34
# Episode 93: CO2 Reduction = -5.35, Fuel Reduction = -1.27
# Episode 94: CO2 Reduction = -0.71, Fuel Reduction = -5.41
# Episode 95: CO2 Reduction = -38.93, Fuel Reduction = -2.09
# Episode 96: CO2 Reduction = 45.35, Fuel Reduction = -2.17
# Episode 97: CO2 Reduction = -43.45, Fuel Reduction = -6.43
# Episode 98: CO2 Reduction = -27.82, Fuel Reduction = -2.32
# Episode 99: CO2 Reduction = 79.22, Fuel Reduction = -2.64
# Episode 100: CO2 Reduction = 120.78, Fuel Reduction = -0.53
# Episode 101: CO2 Reduction = 82.26, Fuel Reduction = 6.61
# Episode 102: CO2 Reduction = 25.26, Fuel Reduction = 2.31
# Episode 103: CO2 Reduction = 11.16, Fuel Reduction = -4.08
# Episode 104: CO2 Reduction = -7.43, Fuel Reduction = 1.63
# Episode 105: CO2 Reduction = 45.93, Fuel Reduction = 1.63
# Episode 106: CO2 Reduction = -19.21, Fuel Reduction = 7.22
# Episode 107: CO2 Reduction = -4.62, Fuel Reduction = 3.16
# Episode 108: CO2 Reduction = -2.14, Fuel Reduction = -1.37
# Episode 109: CO2 Reduction = 39.97, Fuel Reduction = -0.71
# Episode 110: CO2 Reduction = 38.52, Fuel Reduction = -6.89
# Episode 111: CO2 Reduction = 104.69, Fuel Reduction = 7.36
# Episode 112: CO2 Reduction = 50.26, Fuel Reduction = -8.36
# Episode 113: CO2 Reduction = 82.10, Fuel Reduction = -2.06
# Episode 114: CO2 Reduction = 40.28, Fuel Reduction = 2.79
# Episode 115: CO2 Reduction = -15.83, Fuel Reduction = 6.26
# Episode 116: CO2 Reduction = 14.64, Fuel Reduction = 3.41
# Episode 117: CO2 Reduction = -78.54, Fuel Reduction = 0.30
# Episode 118: CO2 Reduction = -124.31, Fuel Reduction = 6.14
# Episode 119: CO2 Reduction = -20.50, Fuel Reduction = -2.60
# Episode 120: CO2 Reduction = 37.60, Fuel Reduction = 3.69
# Episode 121: CO2 Reduction = -94.36, Fuel Reduction = -1.20
# Episode 122: CO2 Reduction = -18.20, Fuel Reduction = 0.88
# Episode 123: CO2 Reduction = -10.77, Fuel Reduction = 2.19
# Episode 124: CO2 Reduction = 20.37, Fuel Reduction = -5.00
# Episode 125: CO2 Reduction = -2.09, Fuel Reduction = 4.93
# Episode 126: CO2 Reduction = -70.18, Fuel Reduction = -1.84
# Episode 127: CO2 Reduction = 7.75, Fuel Reduction = -3.19
# Episode 128: CO2 Reduction = -79.80, Fuel Reduction = -0.77
# Episode 129: CO2 Reduction = 11.82, Fuel Reduction = 0.02
# Episode 130: CO2 Reduction = -6.73, Fuel Reduction = -4.09
# Episode 131: CO2 Reduction = 106.99, Fuel Reduction = -2.32
# Episode 132: CO2 Reduction = 14.09, Fuel Reduction = 0.69
# Episode 133: CO2 Reduction = 4.91, Fuel Reduction = -1.92
# Episode 134: CO2 Reduction = 4.98, Fuel Reduction = -1.89
# Episode 135: CO2 Reduction = -13.76, Fuel Reduction = -0.26
# Episode 136: CO2 Reduction = 58.88, Fuel Reduction = -2.90
# Episode 137: CO2 Reduction = -31.91, Fuel Reduction = 3.32
# Episode 138: CO2 Reduction = 27.81, Fuel Reduction = -3.42
# Episode 139: CO2 Reduction = 40.69, Fuel Reduction = 3.14
# Episode 140: CO2 Reduction = -37.22, Fuel Reduction = -2.96
# Episode 141: CO2 Reduction = 94.97, Fuel Reduction = -4.54
# Episode 142: CO2 Reduction = 67.73, Fuel Reduction = 7.64
# Episode 143: CO2 Reduction = 41.32, Fuel Reduction = 0.77
# Episode 144: CO2 Reduction = -0.39, Fuel Reduction = -1.00
# Episode 145: CO2 Reduction = -55.36, Fuel Reduction = 1.79
# Episode 146: CO2 Reduction = 37.68, Fuel Reduction = 3.46
# Episode 147: CO2 Reduction = -48.66, Fuel Reduction = 1.73
# Episode 148: CO2 Reduction = -17.31, Fuel Reduction = 0.74
# Episode 149: CO2 Reduction = -109.26, Fuel Reduction = 4.63
# Episode 150: CO2 Reduction = -38.26, Fuel Reduction = -3.25
# Episode 151: CO2 Reduction = -29.15, Fuel Reduction = -1.14
# Episode 152: CO2 Reduction = -137.96, Fuel Reduction = 3.24
# Episode 153: CO2 Reduction = -97.83, Fuel Reduction = -4.94
# Episode 154: CO2 Reduction = 55.42, Fuel Reduction = -4.27
# Episode 155: CO2 Reduction = 61.51, Fuel Reduction = -0.42
# Episode 156: CO2 Reduction = -90.62, Fuel Reduction = 2.97
# Episode 157: CO2 Reduction = 12.88, Fuel Reduction = -4.21
# Episode 158: CO2 Reduction = -78.77, Fuel Reduction = 0.84
# Episode 159: CO2 Reduction = -43.56, Fuel Reduction = 0.32
# Episode 160: CO2 Reduction = 68.24, Fuel Reduction = 2.75
# Episode 161: CO2 Reduction = -68.53, Fuel Reduction = 1.30
# Episode 162: CO2 Reduction = -6.87, Fuel Reduction = -4.59
# Episode 163: CO2 Reduction = -43.47, Fuel Reduction = 4.78
# Episode 164: CO2 Reduction = -20.56, Fuel Reduction = 8.07
# Episode 165: CO2 Reduction = -3.02, Fuel Reduction = -2.82
# Episode 166: CO2 Reduction = 102.42, Fuel Reduction = -0.79
# Episode 167: CO2 Reduction = 45.22, Fuel Reduction = -1.29
# Episode 168: CO2 Reduction = -92.14, Fuel Reduction = -1.53
# Episode 169: CO2 Reduction = -94.27, Fuel Reduction = -4.71
# Episode 170: CO2 Reduction = 5.75, Fuel Reduction = -0.46
# Episode 171: CO2 Reduction = 43.96, Fuel Reduction = 2.07
# Episode 172: CO2 Reduction = -46.40, Fuel Reduction = -0.09
# Episode 173: CO2 Reduction = -44.27, Fuel Reduction = -1.61
# Episode 174: CO2 Reduction = -83.90, Fuel Reduction = -3.70
# Episode 175: CO2 Reduction = -103.12, Fuel Reduction = -4.01
# Episode 176: CO2 Reduction = -120.04, Fuel Reduction = 0.42
# Episode 177: CO2 Reduction = 72.92, Fuel Reduction = -1.38
# Episode 178: CO2 Reduction = 58.52, Fuel Reduction = -4.65
# Episode 179: CO2 Reduction = 68.83, Fuel Reduction = -7.03
# Episode 180: CO2 Reduction = -113.13, Fuel Reduction = -1.99
# Episode 181: CO2 Reduction = 13.87, Fuel Reduction = -6.35
# Episode 182: CO2 Reduction = -100.89, Fuel Reduction = -3.81
# Episode 183: CO2 Reduction = -11.77, Fuel Reduction = 5.69
# Episode 184: CO2 Reduction = -33.85, Fuel Reduction = 2.43
# Episode 185: CO2 Reduction = -12.57, Fuel Reduction = 1.47
# Episode 186: CO2 Reduction = 47.66, Fuel Reduction = 1.59
# Episode 187: CO2 Reduction = -25.88, Fuel Reduction = 3.78
# Episode 188: CO2 Reduction = 42.44, Fuel Reduction = 4.35
# Episode 189: CO2 Reduction = -33.87, Fuel Reduction = -0.67
# Episode 190: CO2 Reduction = 28.23, Fuel Reduction = 2.89
# Episode 191: CO2 Reduction = -16.86, Fuel Reduction = 0.02
# Episode 192: CO2 Reduction = -66.41, Fuel Reduction = 4.01
# Episode 193: CO2 Reduction = 36.63, Fuel Reduction = 4.62
# Episode 194: CO2 Reduction = -18.15, Fuel Reduction = 2.04
# Episode 195: CO2 Reduction = -23.51, Fuel Reduction = 2.18
# Episode 196: CO2 Reduction = -29.51, Fuel Reduction = -2.55
# Episode 197: CO2 Reduction = 68.82, Fuel Reduction = 2.78
# Episode 198: CO2 Reduction = 23.49, Fuel Reduction = -4.96
# Episode 199: CO2 Reduction = 53.31, Fuel Reduction = 5.97
# Episode 200: CO2 Reduction = -105.35, Fuel Reduction = -5.96
# Episode 201: CO2 Reduction = -34.14, Fuel Reduction = -5.96
# Episode 202: CO2 Reduction = -69.40, Fuel Reduction = -6.41
# Episode 203: CO2 Reduction = -1.57, Fuel Reduction = 0.28
# Episode 204: CO2 Reduction = 72.62, Fuel Reduction = 6.12
# Episode 205: CO2 Reduction = -128.14, Fuel Reduction = -3.19
# Episode 206: CO2 Reduction = 55.42, Fuel Reduction = 0.33
# Episode 207: CO2 Reduction = 43.74, Fuel Reduction = -0.02
# Episode 208: CO2 Reduction = -95.74, Fuel Reduction = -1.14
# Episode 209: CO2 Reduction = -85.44, Fuel Reduction = 3.44
# Episode 210: CO2 Reduction = -19.74, Fuel Reduction = -1.74
# Episode 211: CO2 Reduction = -52.31, Fuel Reduction = -3.66
# Episode 212: CO2 Reduction = -28.32, Fuel Reduction = 4.80
# Episode 213: CO2 Reduction = 15.97, Fuel Reduction = 0.92
# Episode 214: CO2 Reduction = 9.99, Fuel Reduction = 8.15
# Episode 215: CO2 Reduction = 85.18, Fuel Reduction = 8.08
# Episode 216: CO2 Reduction = 41.37, Fuel Reduction = 3.25
# Episode 217: CO2 Reduction = -91.37, Fuel Reduction = -0.63
# Episode 218: CO2 Reduction = -27.74, Fuel Reduction = 6.61
# Episode 219: CO2 Reduction = 24.17, Fuel Reduction = -3.23
# Episode 220: CO2 Reduction = -88.74, Fuel Reduction = -4.87
# Episode 221: CO2 Reduction = -70.78, Fuel Reduction = -5.11
# Episode 222: CO2 Reduction = 10.42, Fuel Reduction = -2.29
# Episode 223: CO2 Reduction = -115.71, Fuel Reduction = 2.17
# Episode 224: CO2 Reduction = 24.23, Fuel Reduction = 6.40
# Episode 225: CO2 Reduction = -14.05, Fuel Reduction = 0.55
# Episode 226: CO2 Reduction = -39.25, Fuel Reduction = -5.18
# Episode 227: CO2 Reduction = -42.58, Fuel Reduction = -3.56
# Episode 228: CO2 Reduction = -11.88, Fuel Reduction = -1.88
# Episode 229: CO2 Reduction = -2.43, Fuel Reduction = 0.65
# Episode 230: CO2 Reduction = 22.84, Fuel Reduction = 5.09
# Episode 231: CO2 Reduction = 84.57, Fuel Reduction = -4.00
# Episode 232: CO2 Reduction = 57.88, Fuel Reduction = -1.29
# Episode 233: CO2 Reduction = -2.49, Fuel Reduction = 2.90
# Episode 234: CO2 Reduction = -2.49, Fuel Reduction = 1.25
# Episode 235: CO2 Reduction = -38.55, Fuel Reduction = -4.81
# Episode 236: CO2 Reduction = -9.98, Fuel Reduction = -7.20
# Episode 237: CO2 Reduction = -106.42, Fuel Reduction = -0.31
# Episode 238: CO2 Reduction = 74.57, Fuel Reduction = -0.02
# Episode 239: CO2 Reduction = 9.88, Fuel Reduction = 0.25
# Episode 240: CO2 Reduction = -65.70, Fuel Reduction = -6.47
# Episode 241: CO2 Reduction = -106.53, Fuel Reduction = -5.76
# Episode 242: CO2 Reduction = 14.48, Fuel Reduction = 0.14
# Episode 243: CO2 Reduction = -63.97, Fuel Reduction = -3.55
# Episode 244: CO2 Reduction = 51.86, Fuel Reduction = 2.81
# Episode 245: CO2 Reduction = -51.26, Fuel Reduction = -2.94
# Episode 246: CO2 Reduction = -11.57, Fuel Reduction = -1.08
# Episode 247: CO2 Reduction = 36.25, Fuel Reduction = 6.13
# Episode 248: CO2 Reduction = -96.69, Fuel Reduction = -8.11
# Episode 249: CO2 Reduction = 3.83, Fuel Reduction = 2.04
# Episode 250: CO2 Reduction = 18.65, Fuel Reduction = 3.93
# Episode 251: CO2 Reduction = -88.96, Fuel Reduction = -0.25
# Episode 252: CO2 Reduction = 90.24, Fuel Reduction = 6.68
# Episode 253: CO2 Reduction = 52.94, Fuel Reduction = -0.42
# Episode 254: CO2 Reduction = -35.77, Fuel Reduction = -1.15
# Episode 255: CO2 Reduction = -15.64, Fuel Reduction = 0.48
# Episode 256: CO2 Reduction = 71.84, Fuel Reduction = 0.21
# Episode 257: CO2 Reduction = 141.89, Fuel Reduction = -5.05
# Episode 258: CO2 Reduction = 45.17, Fuel Reduction = -5.51
# Episode 259: CO2 Reduction = 19.08, Fuel Reduction = 0.75
# Episode 260: CO2 Reduction = 9.59, Fuel Reduction = 2.69
# Episode 261: CO2 Reduction = 50.52, Fuel Reduction = 4.02
# Episode 262: CO2 Reduction = 69.61, Fuel Reduction = -3.16
# Episode 263: CO2 Reduction = 18.55, Fuel Reduction = -4.04
# Episode 264: CO2 Reduction = -64.83, Fuel Reduction = -0.64
# Episode 265: CO2 Reduction = -76.33, Fuel Reduction = 0.10
# Episode 266: CO2 Reduction = -46.29, Fuel Reduction = 3.57
# Episode 267: CO2 Reduction = -106.69, Fuel Reduction = -4.05
# Episode 268: CO2 Reduction = 99.80, Fuel Reduction = 1.66
# Episode 269: CO2 Reduction = 73.47, Fuel Reduction = -0.43
# Episode 270: CO2 Reduction = 23.98, Fuel Reduction = -5.05
# Episode 271: CO2 Reduction = -37.11, Fuel Reduction = -0.37
# Episode 272: CO2 Reduction = -17.01, Fuel Reduction = -1.40
# Episode 273: CO2 Reduction = 49.86, Fuel Reduction = 4.40
# Episode 274: CO2 Reduction = 17.26, Fuel Reduction = -2.06
# Episode 275: CO2 Reduction = 66.36, Fuel Reduction = -1.56
# Episode 276: CO2 Reduction = -39.89, Fuel Reduction = 2.40
# Episode 277: CO2 Reduction = -6.47, Fuel Reduction = 5.04
# Episode 278: CO2 Reduction = 11.37, Fuel Reduction = 5.98
# Episode 279: CO2 Reduction = 51.73, Fuel Reduction = 2.65
# Episode 280: CO2 Reduction = -30.81, Fuel Reduction = 1.79
# Episode 281: CO2 Reduction = 5.91, Fuel Reduction = -7.41
# Episode 282: CO2 Reduction = 2.54, Fuel Reduction = 2.86
# Episode 283: CO2 Reduction = 105.44, Fuel Reduction = -3.08
# Episode 284: CO2 Reduction = -64.78, Fuel Reduction = 5.72
# Episode 285: CO2 Reduction = 49.64, Fuel Reduction = -1.34
# Episode 286: CO2 Reduction = -94.12, Fuel Reduction = -5.91
# Episode 287: CO2 Reduction = 20.80, Fuel Reduction = 5.53
# Episode 288: CO2 Reduction = 73.50, Fuel Reduction = 1.39
# Episode 289: CO2 Reduction = -15.99, Fuel Reduction = 2.95
# Episode 290: CO2 Reduction = -97.01, Fuel Reduction = -0.66
# Episode 291: CO2 Reduction = -104.97, Fuel Reduction = -2.10
# Episode 292: CO2 Reduction = 66.00, Fuel Reduction = -0.64
# Episode 293: CO2 Reduction = 45.83, Fuel Reduction = 2.70
# Episode 294: CO2 Reduction = 89.33, Fuel Reduction = -3.67
# Episode 295: CO2 Reduction = -98.24, Fuel Reduction = -5.55
# Episode 296: CO2 Reduction = -9.24, Fuel Reduction = -0.27
# Episode 297: CO2 Reduction = -0.37, Fuel Reduction = -1.72
# Episode 298: CO2 Reduction = 112.40, Fuel Reduction = -0.95
# Episode 299: CO2 Reduction = 63.86, Fuel Reduction = -0.03
# Episode 300: CO2 Reduction = 14.85, Fuel Reduction = 1.63
# Episode 301: CO2 Reduction = -20.14, Fuel Reduction = -0.90
# Episode 302: CO2 Reduction = 44.63, Fuel Reduction = -3.98
# Episode 303: CO2 Reduction = -65.12, Fuel Reduction = 0.58
# Episode 304: CO2 Reduction = 45.68, Fuel Reduction = -1.43
# Episode 305: CO2 Reduction = -50.19, Fuel Reduction = -3.97
# Episode 306: CO2 Reduction = 1.48, Fuel Reduction = -2.29
# Episode 307: CO2 Reduction = 8.90, Fuel Reduction = 1.40
# Episode 308: CO2 Reduction = 55.58, Fuel Reduction = 6.26
# Episode 309: CO2 Reduction = -12.92, Fuel Reduction = -2.18
# Episode 310: CO2 Reduction = 28.51, Fuel Reduction = 0.36
# Episode 311: CO2 Reduction = 99.99, Fuel Reduction = -1.07
# Episode 312: CO2 Reduction = -47.40, Fuel Reduction = 2.53
# Episode 313: CO2 Reduction = 95.15, Fuel Reduction = -0.27
# Episode 314: CO2 Reduction = -16.03, Fuel Reduction = -0.44
# Episode 315: CO2 Reduction = 26.79, Fuel Reduction = 3.04
# Episode 316: CO2 Reduction = 95.49, Fuel Reduction = -1.26
# Episode 317: CO2 Reduction = 9.57, Fuel Reduction = -0.39
# Episode 318: CO2 Reduction = 16.80, Fuel Reduction = -5.16
# Episode 319: CO2 Reduction = -22.34, Fuel Reduction = 0.75
# Episode 320: CO2 Reduction = -55.97, Fuel Reduction = -5.61
# Episode 321: CO2 Reduction = 45.50, Fuel Reduction = -4.69
# Episode 322: CO2 Reduction = 44.67, Fuel Reduction = -0.22
# Episode 323: CO2 Reduction = 38.91, Fuel Reduction = -5.71
# Episode 324: CO2 Reduction = 39.01, Fuel Reduction = 7.00
# Episode 325: CO2 Reduction = 24.50, Fuel Reduction = -0.04
# Episode 326: CO2 Reduction = 94.85, Fuel Reduction = -0.33
# Episode 327: CO2 Reduction = 9.28, Fuel Reduction = -4.43
# Episode 328: CO2 Reduction = -99.04, Fuel Reduction = 2.83
# Episode 329: CO2 Reduction = 33.33, Fuel Reduction = -0.45
# Episode 330: CO2 Reduction = 3.55, Fuel Reduction = 4.34
# Episode 331: CO2 Reduction = 27.03, Fuel Reduction = 1.20
# Episode 332: CO2 Reduction = 41.43, Fuel Reduction = -2.20
# Episode 333: CO2 Reduction = -10.91, Fuel Reduction = -1.03
# Episode 334: CO2 Reduction = -36.26, Fuel Reduction = 8.31
# Episode 335: CO2 Reduction = 43.90, Fuel Reduction = 1.92
# Episode 336: CO2 Reduction = -99.86, Fuel Reduction = 1.44
# Episode 337: CO2 Reduction = 37.11, Fuel Reduction = 1.57
# Episode 338: CO2 Reduction = -136.91, Fuel Reduction = 3.38
# Episode 339: CO2 Reduction = -6.46, Fuel Reduction = 6.74
# Episode 340: CO2 Reduction = 2.64, Fuel Reduction = -2.38
# Episode 341: CO2 Reduction = 28.10, Fuel Reduction = 1.91
# Episode 342: CO2 Reduction = 55.04, Fuel Reduction = -0.95
# Episode 343: CO2 Reduction = -30.75, Fuel Reduction = 1.26
# Episode 344: CO2 Reduction = -50.39, Fuel Reduction = -3.36
# Episode 345: CO2 Reduction = -112.47, Fuel Reduction = 6.43
# Episode 346: CO2 Reduction = -22.40, Fuel Reduction = 1.34
# Episode 347: CO2 Reduction = 41.67, Fuel Reduction = 1.38
# Episode 348: CO2 Reduction = -47.06, Fuel Reduction = -7.34
# Episode 349: CO2 Reduction = 63.81, Fuel Reduction = -2.72
# Episode 350: CO2 Reduction = -38.31, Fuel Reduction = -1.30
# Episode 351: CO2 Reduction = -54.14, Fuel Reduction = -0.61
# Episode 352: CO2 Reduction = -50.21, Fuel Reduction = -1.51
# Episode 353: CO2 Reduction = 97.14, Fuel Reduction = 0.32
# Episode 354: CO2 Reduction = -31.25, Fuel Reduction = -0.80
# Episode 355: CO2 Reduction = 44.09, Fuel Reduction = -2.97
# Episode 356: CO2 Reduction = -73.91, Fuel Reduction = 3.20
# Episode 357: CO2 Reduction = 5.40, Fuel Reduction = 3.37
# Episode 358: CO2 Reduction = -35.47, Fuel Reduction = 3.37
# Episode 359: CO2 Reduction = 85.62, Fuel Reduction = 6.37
# Episode 360: CO2 Reduction = -116.30, Fuel Reduction = -1.65
# Episode 361: CO2 Reduction = 52.06, Fuel Reduction = -2.23
# Episode 362: CO2 Reduction = 9.77, Fuel Reduction = -8.44
# Episode 363: CO2 Reduction = 47.26, Fuel Reduction = -0.48
# Episode 364: CO2 Reduction = -129.51, Fuel Reduction = -2.70
# Episode 365: CO2 Reduction = 92.11, Fuel Reduction = 4.51
# Episode 366: CO2 Reduction = -121.81, Fuel Reduction = -1.93
# Episode 367: CO2 Reduction = -1.99, Fuel Reduction = 6.23
# Episode 368: CO2 Reduction = 120.13, Fuel Reduction = 4.74
# Episode 369: CO2 Reduction = -66.69, Fuel Reduction = -7.30
# Episode 370: CO2 Reduction = 92.50, Fuel Reduction = -2.11
# Episode 371: CO2 Reduction = 116.78, Fuel Reduction = -3.57
# Episode 372: CO2 Reduction = -39.92, Fuel Reduction = -0.84
# Episode 373: CO2 Reduction = -87.37, Fuel Reduction = -2.62
# Episode 374: CO2 Reduction = -66.09, Fuel Reduction = -6.66
# Episode 375: CO2 Reduction = -124.83, Fuel Reduction = 4.93
# Episode 376: CO2 Reduction = -106.37, Fuel Reduction = -0.05
# Episode 377: CO2 Reduction = 52.11, Fuel Reduction = 0.78
# Episode 378: CO2 Reduction = -5.31, Fuel Reduction = -0.23
# Episode 379: CO2 Reduction = 13.17, Fuel Reduction = 1.79
# Episode 380: CO2 Reduction = -88.44, Fuel Reduction = -0.12
# Episode 381: CO2 Reduction = 71.68, Fuel Reduction = -5.38
# Episode 382: CO2 Reduction = 42.94, Fuel Reduction = -0.67
# Episode 383: CO2 Reduction = -119.41, Fuel Reduction = -1.12
# Episode 384: CO2 Reduction = -99.87, Fuel Reduction = 0.25
# Episode 385: CO2 Reduction = -7.10, Fuel Reduction = -2.66
# Episode 386: CO2 Reduction = -1.66, Fuel Reduction = -0.12
# Episode 387: CO2 Reduction = -39.92, Fuel Reduction = -0.84
# Episode 388: CO2 Reduction = -25.77, Fuel Reduction = 0.34
# Episode 389: CO2 Reduction = 43.50, Fuel Reduction = 0.71
# Episode 390: CO2 Reduction = -45.63, Fuel Reduction = 0.37
# Episode 391: CO2 Reduction = -37.09, Fuel Reduction = 7.58
# Episode 392: CO2 Reduction = -86.80, Fuel Reduction = -4.85
# Episode 393: CO2 Reduction = -1.82, Fuel Reduction = 3.65
# Episode 394: CO2 Reduction = 25.74, Fuel Reduction = -4.09
# Episode 395: CO2 Reduction = -14.76, Fuel Reduction = 3.76
# Episode 396: CO2 Reduction = -85.94, Fuel Reduction = -2.08
# Episode 397: CO2 Reduction = -26.61, Fuel Reduction = -7.00
# Episode 398: CO2 Reduction = -99.02, Fuel Reduction = 3.57
# Episode 399: CO2 Reduction = -32.61, Fuel Reduction = -5.13
# Episode 400: CO2 Reduction = -3.58, Fuel Reduction = -2.32
# Episode 401: CO2 Reduction = -15.84, Fuel Reduction = -0.14
# Episode 402: CO2 Reduction = -40.82, Fuel Reduction = 0.50
# Episode 403: CO2 Reduction = 5.83, Fuel Reduction = -0.98
# Episode 404: CO2 Reduction = -77.75, Fuel Reduction = 0.91
# Episode 405: CO2 Reduction = 28.04, Fuel Reduction = -4.51
# Episode 406: CO2 Reduction = -34.88, Fuel Reduction = 6.00
# Episode 407: CO2 Reduction = 54.22, Fuel Reduction = 8.28
# Episode 408: CO2 Reduction = -42.73, Fuel Reduction = -1.51
# Episode 409: CO2 Reduction = 42.84, Fuel Reduction = 2.73
# Episode 410: CO2 Reduction = -102.50, Fuel Reduction = 4.90
# Episode 411: CO2 Reduction = -88.43, Fuel Reduction = 1.71
# Episode 412: CO2 Reduction = -14.37, Fuel Reduction = 3.67
# Episode 413: CO2 Reduction = -57.42, Fuel Reduction = -4.53
# Episode 414: CO2 Reduction = 12.04, Fuel Reduction = 4.70
# Episode 415: CO2 Reduction = -12.74, Fuel Reduction = -1.17
# Episode 416: CO2 Reduction = -51.23, Fuel Reduction = 1.09
# Episode 417: CO2 Reduction = -26.19, Fuel Reduction = 2.22
# Episode 418: CO2 Reduction = 58.82, Fuel Reduction = 0.85
# Episode 419: CO2 Reduction = -17.62, Fuel Reduction = -1.63
# Episode 420: CO2 Reduction = 101.29, Fuel Reduction = 0.38
# Episode 421: CO2 Reduction = 26.80, Fuel Reduction = 8.25
# Episode 422: CO2 Reduction = -81.23, Fuel Reduction = 1.01
# Episode 423: CO2 Reduction = -29.76, Fuel Reduction = -0.58
# Episode 424: CO2 Reduction = -21.53, Fuel Reduction = -6.28
# Episode 425: CO2 Reduction = 13.91, Fuel Reduction = 4.14
# Episode 426: CO2 Reduction = -2.89, Fuel Reduction = -1.64
# Episode 427: CO2 Reduction = 48.13, Fuel Reduction = 2.11
# Episode 428: CO2 Reduction = -2.79, Fuel Reduction = 1.40
# Episode 429: CO2 Reduction = 61.10, Fuel Reduction = 1.11
# Episode 430: CO2 Reduction = -108.56, Fuel Reduction = 2.27
# Episode 431: CO2 Reduction = -22.65, Fuel Reduction = 5.87
# Episode 432: CO2 Reduction = -32.90, Fuel Reduction = -2.65
# Episode 433: CO2 Reduction = -13.11, Fuel Reduction = 0.18
# Episode 434: CO2 Reduction = -45.95, Fuel Reduction = 7.91
# Episode 435: CO2 Reduction = 47.47, Fuel Reduction = -1.34
# Episode 436: CO2 Reduction = 2.93, Fuel Reduction = -4.74
# Episode 437: CO2 Reduction = 31.75, Fuel Reduction = -3.31
# Episode 438: CO2 Reduction = -28.10, Fuel Reduction = 5.99
# Episode 439: CO2 Reduction = 112.00, Fuel Reduction = 4.26
# Episode 440: CO2 Reduction = 102.37, Fuel Reduction = 4.19
# Episode 441: CO2 Reduction = -63.12, Fuel Reduction = 1.51
# Episode 442: CO2 Reduction = 15.06, Fuel Reduction = -1.02
# Episode 443: CO2 Reduction = -31.03, Fuel Reduction = -2.04
# Episode 444: CO2 Reduction = -37.39, Fuel Reduction = 2.72
# Episode 445: CO2 Reduction = 12.45, Fuel Reduction = -3.09
# Episode 446: CO2 Reduction = 1.71, Fuel Reduction = 4.64
# Episode 447: CO2 Reduction = -40.35, Fuel Reduction = -0.69
# Episode 448: CO2 Reduction = -59.13, Fuel Reduction = -0.23
# Episode 449: CO2 Reduction = 13.88, Fuel Reduction = 3.23
# Episode 450: CO2 Reduction = 25.47, Fuel Reduction = 3.08
# Episode 451: CO2 Reduction = -11.91, Fuel Reduction = 2.13
# Episode 452: CO2 Reduction = 16.25, Fuel Reduction = -0.31
# Episode 453: CO2 Reduction = -28.03, Fuel Reduction = 2.50
# Episode 454: CO2 Reduction = 50.34, Fuel Reduction = -7.40
# Episode 455: CO2 Reduction = 8.78, Fuel Reduction = -2.60
# Episode 456: CO2 Reduction = 16.27, Fuel Reduction = -0.73
# Episode 457: CO2 Reduction = 27.04, Fuel Reduction = 7.52
# Episode 458: CO2 Reduction = -17.23, Fuel Reduction = 2.86
# Episode 459: CO2 Reduction = -16.92, Fuel Reduction = -0.53
# Episode 460: CO2 Reduction = 8.06, Fuel Reduction = -1.47
# Episode 461: CO2 Reduction = -44.37, Fuel Reduction = -0.97
# Episode 462: CO2 Reduction = -2.89, Fuel Reduction = 1.34
# Episode 463: CO2 Reduction = -57.96, Fuel Reduction = -0.73
# Episode 464: CO2 Reduction = 91.48, Fuel Reduction = -2.45
# Episode 465: CO2 Reduction = 82.55, Fuel Reduction = -7.76
# Episode 466: CO2 Reduction = 59.06, Fuel Reduction = -0.30
# Episode 467: CO2 Reduction = -45.64, Fuel Reduction = 2.28
# Episode 468: CO2 Reduction = 21.76, Fuel Reduction = 1.54
# Episode 469: CO2 Reduction = 5.06, Fuel Reduction = -6.18
# Episode 470: CO2 Reduction = 11.66, Fuel Reduction = 0.14
# Episode 471: CO2 Reduction = -65.55, Fuel Reduction = -2.25
# Episode 472: CO2 Reduction = 12.62, Fuel Reduction = -0.51
# Episode 473: CO2 Reduction = 80.83, Fuel Reduction = -0.23
# Episode 474: CO2 Reduction = 65.52, Fuel Reduction = -2.12
# Episode 475: CO2 Reduction = -110.02, Fuel Reduction = 5.75
# Episode 476: CO2 Reduction = -20.07, Fuel Reduction = -0.48
# Episode 477: CO2 Reduction = -13.13, Fuel Reduction = -4.44
# Episode 478: CO2 Reduction = -76.79, Fuel Reduction = 1.71
# Episode 479: CO2 Reduction = -93.77, Fuel Reduction = -6.69
# Episode 480: CO2 Reduction = 28.81, Fuel Reduction = 0.83
# Episode 481: CO2 Reduction = -78.98, Fuel Reduction = 6.05
# Episode 482: CO2 Reduction = 104.94, Fuel Reduction = 2.46
# Episode 483: CO2 Reduction = 13.22, Fuel Reduction = -0.08
# Episode 484: CO2 Reduction = 75.96, Fuel Reduction = 4.13
# Episode 485: CO2 Reduction = 24.90, Fuel Reduction = 6.52
# Episode 486: CO2 Reduction = 5.48, Fuel Reduction = -2.96
# Episode 487: CO2 Reduction = -2.61, Fuel Reduction = 1.27
# Episode 488: CO2 Reduction = -50.79, Fuel Reduction = 2.07
# Episode 489: CO2 Reduction = 43.34, Fuel Reduction = 7.46
# Episode 490: CO2 Reduction = -23.92, Fuel Reduction = -3.47
# Episode 491: CO2 Reduction = -90.82, Fuel Reduction = -1.62
# Episode 492: CO2 Reduction = -7.25, Fuel Reduction = 1.81
# Episode 493: CO2 Reduction = 37.61, Fuel Reduction = -1.80
# Episode 494: CO2 Reduction = 1.37, Fuel Reduction = -2.21
# Episode 495: CO2 Reduction = -57.53, Fuel Reduction = -1.48
# Episode 496: CO2 Reduction = -104.50, Fuel Reduction = -5.40
# Episode 497: CO2 Reduction = 24.25, Fuel Reduction = 1.20
# Episode 498: CO2 Reduction = 47.98, Fuel Reduction = 1.65
# Episode 499: CO2 Reduction = 46.83, Fuel Reduction = -4.41
# Episode 500: CO2 Reduction = 38.20, Fuel Reduction = 4.22
# Training complete!
